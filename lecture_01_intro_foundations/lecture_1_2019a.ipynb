# %% [markdown]
# ---

# %% [markdown]
# # Artificial Intelligence - COMPSCI4004 2018-2019

# %% [markdown]
# <h2> Week 1: Introduction & Foundations</h2><span style="font-size:0.5em">Version: 2019a</span>

# %% [markdown]
# Bjørn Sand Jensen (aka Bjoern, Bjorn), <br>
# bjorn.jensen@glasgow.ac.uk <br>
# School of Computing Science, University of Glasgow, SAWB 306<br>

# %% [markdown]
# ------

# %% [markdown]
# ## Lecture 1: Introduction & Foundation

# %% [markdown]
# ### Reading & Learning Objectives

# %% [markdown]
# <div class="alert alert-danger">
# <font color=black>
# <b>Reading: </b><br>
# - AIMA: Chapter 1 and 2<br>
# - Computing Machinery and Intelligence, A. M. Turing, 1950<br>
# - Attempt the weekly quiz<br>
# <br>
# No need to memorize names and dates of individual scientist and events.<br>
# <br>
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font color=black>
# <b>Learning objectives:</b><br>
# - Become familiar with the history of AI, its definition and its development<br>
# - Understand the definition of rational agents<br>
# - Be able to take a description of an application domain and break it down to a PEAS description<br>
# - Be able to explain the basic agent types and their limitations<br>
# - Be able to analyse and discuss the features of an environment (e.g. accessibility, deterministic, dynamic, continuous, episodic)<br>
# </font>
# <br>
# </div>

# %% [markdown]
# ----

# %% [markdown]
# ### Motivation & Examples

# %% [markdown]
# [<h4>Expert Systems (1970-1980s)</h4>](https://en.wikipedia.org/wiki/Expert_system)
# <img src="resources/mycin.png" width="600px">
# <center>MYCIN for detecting bacteria</center>

# %% [markdown]
# ----
# [<h4>Deep Blue (1997)</h4>](http://www-03.ibm.com/ibm/history/ibm100/us/en/icons/deepblue/)
# <img src="resources/deepblue.jpg" width="600px">
# <center>Image: IBM</center>

# %% [markdown]
# ----
# [<h4>Asimo (2000 - )</h4>](http://asimo.honda.com/)

# %%
from IPython.display import YouTubeVideo
from datetime import timedelta
start=int(timedelta(hours=0, minutes=3, seconds=55).total_seconds())
YouTubeVideo("JlRPICfnmhw", start=start, autoplay=0, theme="light", color="red")

# %% [markdown]
# ----
# [Watson (2011 - )](http://www.techrepublic.com/article/ibm-watson-the-inside-story-of-how-the-jeopardy-winning-supercomputer-was-born-and-what-it-wants-to-do-next/)
#
# <img src="resources/watson-jeopardy-940px.jpg" width="700px">
# <center>Image: IBM</center>

# %% [markdown]
# ----
# [<h4>Google Car (2010's - )</h4>](https://www.google.com/selfdrivingcar/)

# %%
from IPython.display import YouTubeVideo
from datetime import timedelta
start=int(timedelta(hours=0, minutes=0, seconds=27).total_seconds())
YouTubeVideo("CqSDWoAhvLU", start=start, autoplay=0, theme="light", color="red")#, width=1024, height=800)

# %% [markdown]
# <center>Video: Google, https://www.youtube.com/watch?v=CqSDWoAhvLU, YouTube standard license</center>

# %% [markdown]
# ----
# [<h4>Tesla Car (2015's - )</h4>](https://www.google.com/selfdrivingcar/)

# %%
from IPython.display import YouTubeVideo
from datetime import timedelta
start=int(timedelta(hours=0, minutes=0, seconds=1).total_seconds())
YouTubeVideo("VG68SKoG7vE", start=start, autoplay=0, theme="light", color="red")#, width=1024, height=800)

# %% [markdown]
# <center>Video/license: Tesla, https://www.tesla.com/videos/autopilot-self-driving-hardware-neighborhood-long?redirect=no</center>

# %% [markdown]
# ----
# [<h4>AlphaGo (2015 - )</h4>](https://deepmind.com/research/alphago/)

# %%
from IPython.display import YouTubeVideo
start=int(timedelta(hours=0, minutes=3, seconds=10).total_seconds())
YouTubeVideo("g-dKXOlsf98", start=start, autoplay=0, theme="light", color="red")#, width=1024, height=800)

# %% [markdown]
# <center>Video: Google, https://www.youtube.com/watch?v=CqSDWoAhvLU, YouTube standard license</center>

# %% [markdown]
# ---

# %% [markdown]
# ----
# [<h4>Music Generation (2017 - )</h4>](https://magenta.tensorflow.org)

# %%
from IPython.display import YouTubeVideo
start=int(timedelta(hours=0, minutes=3, seconds=10).total_seconds())
YouTubeVideo("OsxP4lFp76I", start=start, autoplay=0, theme="light", color="red")#, width=1024, height=800)

# %% [markdown]
# <img src="resources/perfrnn.png" width="600px" border="1">
# <center>Image: Google Magenta</center>
#
# Demos at: https://magenta.tensorflow.org/performance-rnn

# %% [markdown]
# ---

# %% [markdown]
# ----
# [<h4>Boston Dynamics (ca 2018)</h4>](https://www.bostondynamics.com/)

# %%
from IPython.display import YouTubeVideo
start=int(timedelta(hours=0, minutes=0, seconds=20).total_seconds())
YouTubeVideo("vjSohj-Iclc", start=start, autoplay=0, theme="light", color="red")#, width=1024, height=800)

# %% [markdown]
# ----
# [<h4>Search Engines & Recommendation</h4>](http://www.google.com)
#
#
# <img src="resources/amazon.png" width="700px" border="1">
# <center>Image: Amazon</center>
#
# ---
#
# <img src="resources/google.png" width="700px" border="1">
# <center>Image: Google</center>

# %% [markdown]
# ----
# [<h4>Cognitive Psychology (2015)</h4>](http://web.mit.edu/cocosci/Papers/Science-2015-Lake-1332-8.pdf)

# %%
from IPython.display import HTML
HTML('<iframe src=resources/laketennemabum2015.pdf width=700 height=1600></iframe>')
# Out:
# <iframe src=resources/laketennemabum2015.pdf width=700 height=1600></iframe>

# %% [markdown]
# ----

# %% [markdown]
# ----
# [<h4>Twitter and Natural Languge Processing</h4>](https://twitter.com/deepdrumpf?lang=en)
#
#
# <img src="resources/chatbottwitter.png" width="700px" border="1">
# <center>Image: Twitter, https://twitter.com/deepdrumpf</center>

# %% [markdown]
# ---
#
# ** Common characteristics:**
#
# - Sensing, perception
# - Knowledge representation
# - Reasoning (problem solving, planning) and decision-making
# - (Imagining, creating, communication,...)
# - Learning / adapting / self-improvement
# - Acting
# - ...

# %% [markdown]
# ----

# %% [markdown]
# ### Course Overview

# %% [markdown]
# ####  Course Objectives

# %% [markdown]
# <br>
# <div class="alert alert-warning">
# <font color=black>
# 1. Demonstrate familiarity with the history of AI, philosophical debates, and understand the potential and limitations of the subject in its current form;<br>
# 2. Explain the basic components of an intelligent agent, and be able to map these onto other advanced subjects such as information retrieval, computer vision, database systems, robotics, human-computer interaction, reactive systems etc;<br>
# 3. Discuss basic issues in planning;<br>
# 4. Describe and apply search-based problem-solving techniques;<br>
# 5. Formulate and apply Bayesian networks in modelling and planning;<br>
# 6. Describe and apply utility theory as a probabilistic framework for rational decision making;<br>
# 7. Describe and apply machine learning techniques to learn from observations;<br>
# 8. Discuss difficulties in computer perception. <br>
#
# <br>Prerequisites<br>
# - Level 1 mathematics or equivalent; working knowledge of matrices, linear spaces and basic geometry. <br>
# - Fluency in a high-level programming language such as Java or Python<br>
# - * Data Fundamentals or equivalent; working knowledge of vector spaces, numerical analysis/optimisation and probability.<br>
# <br>
# </font>
# </div>

# %% [markdown]
# ----

# %% [markdown]
# #### Recommended textbooks

# %% [markdown]
# <img src="resources/aima_front_cover_3rd.jpg" width="250px">
# <center>http://aima.cs.berkeley.edu/</center>
#
#
# - Also:
#  - Pattern recognition and machine learning (free), https://www.microsoft.com/en-us/research/uploads/prod/2006/01/Bishop-Pattern-Recognition-and-Machine-Learning-2006.pdf
#  - Reinforcement learning - an introduction, seond edition (free), http://incompleteideas.net/book/the-book-2nd.html
#  - Machine Learning for Audio, Image and Video Analysis, Francesco Camastra and Alessandro Vinciarelli, www.dcs.gla.ac.uk/vincia/textbook.pdf
#   - Bayesian Reasoning and Machine Learning, David Barber, web4.cs.ucl.ac.uk/staff/D.Barber/textbook/270212.pdf

# %% [markdown]
# -----

# %% [markdown]
# ### Time schedule and venues

# %% [markdown]
# #### Lectures:
#
# - Thursday 12.00-14.00 Thomson Building 236

# %% [markdown]
# #### Assesment

# %% [markdown]
# * Assessed Exercise (20%)
#  * Individual project
#  * This year you will analyse, design, implement and evaluate an intelligent agent for solving a reinforcement learning problem in the openai gym environment https://gym.openai.com.
#
# * Exam (80%)
#  * 2 hour written
#
# * Examinable material:
#     * Textbook(s) - examinable sections will be explicitly defined
#     * Slides/lecture where explicity specified
#     * Specific research articles

# %% [markdown]
# #### Labs

# %% [markdown]
# * Boyd Orr Level Lab (1028)
# * IT / Computer resources
#     * Python 3.6+
#     * Slides and labs will be presented primarily as Python/Jupyter Notebooks

# %% [markdown]
# #### Help & Support

# %% [markdown]
# * General questions should be posted on Moodle
#
# * Specific or personal issues should be discussed by e-mail or face-to-face.
#
# * Office hours
#     * Your are welcome to drop by SAWB 306 anytime, but I might not be in or have time to talk. Send a e-mail to schedule a meeting

# %% [markdown]
# --------------

# %% [markdown]
# ### What is AI ?

# %% [markdown]
# <br>
# <div class="alert alert-warning">
# <font color=black>
#
# "It is the science and engineering of making intelligent machines, especially
# intelligent computer programs. It is related to the similar task of
# using computers to understand human intelligence, but AI does not have to
# confine itself to methods that are biologically observable.",
#
# <br>
# <br>
#
# John McCarthy, 2007, Stanford, http://www-formal.stanford.edu/jmc/whatisai.pdf
#
#
# </font>
# </div>
#
# <br>
# <div class="alert alert-warning">
# <font color=black>
# “The science of making machines do things that would require intelligence if done by men.",
# <br>
# <br>
# Marvin Minsky, 60's
# </font>
# </div>

# %% [markdown]
# ----

# %% [markdown]
# ### ... what is ___natural___ intelligence ?

# %% [markdown]
# <br>
# <div class="alert alert-warning">
# <font color=black>
# "A very general mental capability that, among other things, involves the ability to reason, plan, solve problems, think abstractly, comprehend complex ideas, learn quickly and learn from experience. It is not merely book learning, a narrow academic skill, or test-taking smarts. Rather, it reflects a broader and deeper capability for comprehending our surroundings—"catching on," "making sense" of things, or "figuring out" what to do"
#
# <br>
# <br>
#
# Gottfredson LS. Mainstream science on intelligence: An editorial with 52 signatories, history, and bibliography. Intelligence. 1997a;24:13–23. [52 out of 113 signed]
# </font>
# </div>

# %% [markdown]
# ----

# %% [markdown]
# ** A nuanced view: **

# %% [markdown]
# <img src="resources/aiquotes.png" width="700px">
#
#
# <img src="resources/whatisai2.png" width="700px">

# %% [markdown]
# ----

# %% [markdown]
# #### Acting Humanly - A. M. Turing

# %% [markdown]
# <img src="resources/turing.png" width="600px">
# <center>The Turing Test</center>
#
# Turing (1950), Computing Machinery and intelligence:
# - Instead of <font color=red>“Can machines think?”</font> ask <font color=red>“Can machines do what we (as thinking entities) can do?”</font>
# - An operational test for intelligent behaviour is “The Imitation Game”
# - Predicted that by the year 2000 a machine might have a 30% chance of fooling a lay person for 5 minutes.
# anticipated major arguments against AI, and suggested components of AI, such as knowledge, reasoning, language, understanding, learning.
# - Not a major AI goal (not reproducible, constructive or amenable to mathematical analysis) – mostly interesting when intelligent systems interact with humans.

# %% [markdown]
# ----

# %% [markdown]
# #### Thinking humanly - Cognitive science

# %% [markdown]
# 1960’s “cognitive revolution”: information-processing psychology (‘natural computation’) replaced prevailing orthodoxy of behaviourism.
#
# Requires scientific theories of internal activities of the brain:
# - What level of abstraction? Knowledge or circuits.
# - How to validate:
#     - Predicting & testing behaviour of human subjects, top-down = Cognitive Science
#     - Direct identification from neurological data, bottom-up = Cognitive Neuroscience.
#
# Once a theory of mind becomes precise, enough we can build a computer program to implement it. AI allows us to test psychology hypotheses against experimental data.

# %% [markdown]
# ----

# %% [markdown]
# #### Thinking rationally: ___Laws of Thought___

# %% [markdown]
# - Normative (or prescriptive) rather than descriptive
#
# - Roots in Greek philosophy, direct line through mathematics to modern AI
#
# - Problems:
#  - Not all intelligent behaviour is mediated by logical deliberation
#  - What is the purpose of thinking? What thoughts should I have out of all the thoughts (logical or otherwise) that I could have?
#  - Problems with formalisation of informal knowledge – especially under uncertainty
#  - Problems with computational resources when performing inference in practice

# %% [markdown]
# ----

# %% [markdown]
# #### Acting rationally

# %% [markdown]
# Rational behaviour: <font color="blue">Do the right thing</font>.
#
# * The right thing is to maximize the best (expected) outcome given the available information.
# * Does not need to involve thinking (e.g. could be purely reflex-based), but any thinking should be in the service of rational action.
#
# Computational limitations make perfect rationality unachievable, so we must have best program given machine resources (**limited/bounded** rationality)
#
# ___We will adopt this notion of rationality for designing "intelligent agents" in this course!___

# %% [markdown]
# ------------------

# %% [markdown]
# ### History of AI

# %% [markdown]
# #### Prehistory and AI as a multidisciplinary field

# %% [markdown]
# <img src="resources/prehistory.png" width="450px">
#
#
# * At the time (1940 / 1950s) none of these field had the combined goal of AI, including understanding internal processes of the mind (psychology focused on behaviourism), self-improvement, creativity and language use.

# %% [markdown]
# ----

# %% [markdown]
# #### Development of AI as a field

# %% [markdown]
# <table border=0 cellpadding=0 cellspacing=0 width=500 style='border-collapse:
#  collapse;table-layout:fixed;width:500pt'>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  width=102 style='text-align:left;height:15.0pt;width:77pt'>1943</td>
#   <td style='text-align:left'>McCulloch &amp; Pitts: Boolean circuit
#   model of the brain/neuron</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1950</td>
#   <td style='text-align:left'>Turing: Computing Machinery and Intelligence</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1952-69</td>
#   <td style='text-align:left'>Look, Ma, no hands! *<span style='mso-spacerun:yes'> </span></td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1950s</td>
#   <td style='text-align:left'>Early AI programs, including Samuels's checkers programs, Newell &amp;
#   Simon's Logic Theorist, Gelernters's Geometry Engine</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1956</td>
#   <td style='text-align:left'>Dartmouth meeting: &quot;Artificial intelligence&quot; adopted</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1965</td>
#   <td style='text-align:left'>Robinsons's complete algorithms for logical reasoning</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1966-74</td>
#   <td style='text-align:left'>AI runs into computational complexity and lack of computational power</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>Neural network research almost disappears</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1974-1980</td>
#   <td style='text-align:left'>AI Winther, Lighthill report cuts funding in the UK</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1969-79</td>
#   <td style='text-align:left'>Early adoption of knowledge-based systems (rule based)</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1980-88</td>
#   <td style='text-align:left'>Expert system industry booms</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1988-93</td>
#   <td style='text-align:left'>Expert system industry burst: AI wither</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1985-95</td>
#   <td style='text-align:left'>Neural networks research wave (many of the current structures were
#   invented in the 80/90s)</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1988-</td>
#   <td style='text-align:left'>Scientific method, probability and decision-theoretic methods</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>Increase in technical depts of mainstream AI</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>Nouvell AI / embodied reasoning: Alife, GAs, soft computing</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>1995-</td>
#   <td style='text-align:left'>Intelligent agents - the rational agent approach</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>2005 Deep Blue</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>2011 Watson: Jeopardy</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>2005 Darpa challenge: Self-driving cars</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>2001-</td>
#   <td style='text-align:left'>Big data and deep neural networks</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>2005 20-30% gain in ASR performance using deep neural networks</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>2011 General purpose self-driving cars</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>2012 10% point performance gain on images (ImageNet) using AlexNet</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>2015 / 2017 Alpha Go and Alpha Go Zero</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'></td>
#   <td style='text-align:left'>2015- Realistic generation of images, videos and music/audio</td>
#  </tr>
#  <tr height=20 style='text-align:left;height:15.0pt'>
#   <td height=20  style='text-align:left;height:15.0pt'>2003-</td>
#   <td style='text-align:left'>Human level AI back on the agenda.</td>
#  </tr>
# </table>
#
# * See e.g. http://www-formal.stanford.edu/jmc/reviews/lighthill/lighthill.html

# %% [markdown]
# ----

# %% [markdown]
# ### Expectations & Limitations

# %% [markdown]
# What is possible today (2019) ?
#
# * Drive safely along a curving mountain road
# * Drive safely along University Avenue
# * Buy a week’s worth of groceries on the web
# * Play a decent game of bridge / Go / Chess
# * Discover and prove a new mathematical theorem
# * Design and execute a research program in molecular biology
# * Write an intentionally funny story
# * Give competent legal advice in a specialized area of law
# * Translate spoken English into spoken Swedish in real time
# * Converse successfully with another person for an hour
# * Perform a complex surgical operation
# * Unload any dishwasher and put everything away
# * Play a decent game of table tennis
# * Explain your feeling and emotions to others
# * Learn, adapt and develop over several decades
# * Learn a new motor skill from a few examples
# * ...

# %% [markdown]
# Progress (using e.g. deep neural networks) has mainly been on stand-alone pattern recognition tasks and driven by gains in comptational power and massive amounts of data (or simulation).
#
# Regardless if we are looking at solving domain-specific tasks or aim to achive human level AI, there are clearly still open questions related to for example:
#
# - Sensing, perception (including object recognition)
# - Knowledge representation
# - Reasoning (problem solving, planning, ...
# - Imagining, creating, explaining/understanding and communication
# - Self-awareness and consciousness
# - Learning / adapting / self-improvement (across difficent task and over long timeperiods)
# - Acting

# %% [markdown]
# ----

# %% [markdown]
# ### Why study AI?

# %% [markdown]
# **Science & Philosophy**:
# - Attempt to understand humans - learn more about ourselves.
# - Attempt to understand the general principles for modelling intelligent systems, whether human, animal or artifact.
# - Often inspired by research in philosophy, psychology, linguistics, etc., and often leads to new work in those fields. The very difficulty of creating intelligent systems makes us appreciate how complex and subtle the brain is
# - Help understand intelligence and thinking (e.g. prove the computation theory of mind by building an intelligent machine based on these principles, or perhaps disprove it)
#
# **Engineering:**
# - Unlike philosophy and psychology, we have a need to develop intelligent entities, i.e., design systems which can do things previously only done by humans or animals.
# - Interesting and useful products in their own right
# - Creating human-level intelligence would change civilization, change the way we understand ourselves.
#
# **Regardless, provides an umbrella of tools, techniques, and mindset for solving many  real-world challenges, e.g.**
#  - More clever robotics, cars, industry, service bots, etc. which lead to more freedom (= less work ?)
#  - Entertainment
#  - Increased rate of scientific discovery
#  - Medical diagnostics and treatment
#  - Improved resource management and consumption
#  - ...

# %% [markdown]
# ---
# ** Structure of the course **
#
# Through lectures and labs we will explore the following aspects of AI
#
# - Week 1: Introduction (today) & Foundations
#     * Introduction
#     * Whole-agent view, rationality, and an operational framework.
# - Week 2: Agents with sensors and effectors
#     * Perception, sensors and effectors
# - Week 3: Agents for "simple" problems (i.e. typically fully observable and deterministic)
#     * Search and planning
# - Week 4-5 Agents for "complex" problems
#     * Uncertainty, probability and planning
# - Week 6-9: Agents that learns form observations/rewards
#     * Machine learning for intelligent agents
# - Week 10: Agents of the future
#     * Applications
#     * Ethical issues

# %% [markdown]
# ----

# %% [markdown]
# ### Break

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <h1>
# https://moodle.gla.ac.uk/mod/quiz/view.php?id=766977
# </h1>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ----

# %% [markdown]
# ### Intelligent Agents

# %% [markdown]
# <div class="alert alert-info">
# <font color=black>How to study and build agents in a systematic and principled manner?</font>
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font color=black>
# <b>Definition (AIMA Chapter 2.1):</b>
# <br>
# <br>
# An agent is anything that can be viewed as perceiving its environment through sensors and acting upon that environment through actuators (includes humans, robots, chatbots, thermostats).</font>
# </div>

# %% [markdown]
# <img src="resources/figure21_baseagent2.png" width="500px">
# <small><center>AIMA Figure 2.1, a basic agent. Courtesy of Artificial Intelligence: A Modern Approach (Third edition), Stuart Russell and Peter Norvig</center></small>
#
# ----
#
# The agent function (as implemented by the agent programme) maps from prior/build-in knowledge, $\pi$, and percepts, $\mathcal{P}$, to actions $\mathcal{A}$, i.e. $f:\mathcal{P},\pi\rightarrow\mathcal{A}$
#
#
# *__The percepts__*, $\mathcal{P}$:
# * Perceptual inputs, percepts, and sequence/history as reported by the sensors.
#
# *__The actuators and actions__*, $\mathcal{A}$:
# * What ever means the agent has to influence the environment via its actuators (visual, physical, audio, computer commands,  etc.)
#
# *__The prior knowledge__*, $\mathcal{\pi}$:
# * Any hard coded constraints or knowledge about the environment (e.g. if temperature < -40 degrees, I will not do well)
#
# *__The function__*, $f$:
# - An abstract, external characterization of the agent by a mathematical function which can be represented by mathematical object such as a look-up table, a continuous or discrete function.
# - Internally implemented as a computer program and runs on a physical device

# %% [markdown]
# ------------------

# %% [markdown]
# ### A framework: A system view of intelligent agents based on rationality

# %% [markdown]
# - **<font color=red>P</font>erformance measure**
#      - Defines what "good behaviour" is in a specific context.
#
# - **<font color=red>E</font>nvironment**
#    - A specification of the physical (or virtual) environment the agent is expected to operate in.
#
# - **<font color=red>A</font>ctuators**
#     - The types and physical properties of the actuators available to the agent. Limits what the agent can do.
#
# - **<font color=red>S</font>ensors**
#     - The types and physical properties of the sensors available to the agent. Limita what the agent can know about the environment.
#
#
# <br>
#
# * The aim of the course is to design agents that do a ‘good job’ acting on their environment
#  * What is a good job, i.e. what should the performance measure be?
#  * Criteria that determine how successful an agent is.
#  * No one fixed measure across all tasks, but we insist on an objective measure that an outside authority can establish (i.e. the agent should not itself define what is good.... like humans tend to do).
#  * Better to design performance measures according to what you (as the designer) wants in the environment, rather than how one thinks the agent should behave.

# %% [markdown]
# ----

# %% [markdown]
# <br>
# <div class="alert alert-success">
# <font color=black><b>Example</b>: Designing an vacuum cleaner</font>
# </div>

# %% [markdown]
# <img src="resources/figure23_vac.jpg" width="800px">
#
# <img src="resources/figure22_vacseq.png" width="800px">
# <center>Figure: Courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center>

# %% [markdown]
# ----

# %% [markdown]
# ### Rationality

# %% [markdown]
# <br>
# <div class="alert alert-danger">
# <font color=black>
# <b>Definition (extended version of AIMA Chapter 2.2):</b>
# <br>
# <br>
# For each possible percept (sequence), $\mathcal{P}$, a <b>rational</b> agent selects an action (sequence) that is expected to maximize its performance measure, given the evidence provided by the percept (sequence) and whatever prior/build-in knowledge the agent has.</font>
# </div>
#
# <br>
#
# The goal and success criteria of a agent is measured against a predefined <font color=blue>performance measure</font> . Examples include profit, safely, survival, legal, test score, comfortability, resource consumption, etc.

# %% [markdown]
# ----
# <br>
# <div class="alert alert-success">
#
# <font color=black><b>Example</b>: Designing an automated taxi driver</font>
# <br>
# - <font color=black><b>Performance measure?</b> safety, reach destination, maximise profits, obey laws, passenger comfort...</font><br>
# - <font color=black>Environment?</font><br>
# - <font color=black>Actuators? </font><br>
# - <font color=black>Sensors? </font><br>
# </div>
#
# <br>

# %% [markdown]
# ----
#
# * **Rational IS NOT clairvoyant nor omniscient **
#     - The agent only rarely know the outcome of the action in the environment.
#     - It might have an idea of the outcome based on the percepts and prior knowledge of the environment, and the agents ability to reason based on these, nothing else.
#     - E.g. leaving the house in the morning is considered rational even though there is a remote chance of being hit by a falling brick.
#
#
# * **Rationality DOES NOT imply success**
#     - Being rational therefore does not imply success in solving the task, or if successful any guarantee that it has been solved in any optimal way. I.e. if the performance measure is wrong the agent will typically not solve the actual task by optimizing the measure.
#
#
# * **Rationality CAN LEAD to exploration, learning and autonomy**
#     - Optimization of the performance measure can lead to exploration and information gathering (e.g. speed, value etc).
#     - E.g. not looking before you cross a quiet country road does not make you more rational if you are then hit by a truck! The risk of crossing without looking is too great (loss of performance, i.e. life) - looking helps maximise performance because you are acting to obtain useful information.

# %% [markdown]
# ----

# %% [markdown]
# ### Task and task environment

# %% [markdown]
# - <font color=red>P</font>erformance measure
#      - Defines what "good behaviour" is in a specific context.
#
# - **<font color=red>E</font>nvironment**
#    - A specification of the physical (or virtual) environment the agent is expected to operate in.
#
# - <font color=red>A</font>ctuators
#     - The types and physical properties of the actuators available to the agent. Limits what the agnts can do.
#
# - <font color=red>S</font>ensors
#     - The types and physical properties of the sensors available to the agent. Limit what the agent can know
# about the environment.

# %% [markdown]
# ----

# %% [markdown]
# - __Fully observable vs. partially observable__ (sometimes posed as accessible vs inaccessible)
#     - Fully: Access to all relevant information via the sensors
#     - Partial: If noisy or broken sensors - or sensors simply do not capture the relevant information.
#     - Unobservable: Some times is might be possible to obtain a goal without any observations
# - __Deterministic vs stochastic__
#     - Deterministic: Next state of the environment is fully captured by current state and action to be carried out.
#     - Stochastic: Can not determine the next state based on current state and action due to randomness (or unknowns) in the environment
# - __Static vs dynamic__
#     - Static: The world never changes.
#     - Dynamic: The world changes while we decide what to do, time matters!
#     - Semi: The world is the same, but the performance score changes (e.g. time)
# - __Discrete vs. Continuous__
#     - Discrete: State of the environment are determined among a set of discrete possibilities (e.g. chess), discrete actions (e.g. move left or rigth), discrete percepts (e.g. dirty, not dirty)
#     - Continuous: The world has infinitely many states (e.g. temperature), actions are continuous, percepts are continuous (human vision)
# - __Single agent vs multiple agents__
#     - Single: The agent is alone in the environment
#     - Multi: There are multi agents, either cooperating or competing against each other to fulfill individual or group goals.
# - __Episodic vs sequential__
#     - Episodic: Single actions based on current percept only
#     - Sequential: Current action influences all future decisions
# - __Known vs. unknown__
#     - Do you know the rules of game (e.g. gravity) or how the buttons do befor eyou try them out?

# %% [markdown]
# ----
# <br>
# <div class="alert alert-success">
#
# <font color=black><b>Example</b>: Designing an automated taxi driver</font><br>
#
# <br>
#
# - <font color=black>Performance measure? safety, reach destination, maximise profits, obey laws, passenger comfort...</font><br>
# - <font color=black><b>Environment</b>? urban streets, motorways, traffic, pedestrians, weather, customers...</font><br>
# - <font color=black>Actuators? </font><br>
# - <font color=black>Sensors? </font><br>
# </div>
#
# <br>
# <br>
#
# <img src="resources/figure26_env.jpg" width="800px">
# <small><center>Figure courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center></small>
#
# <br>
#
# * To an agent the real-world is typically....
#  * partially observable
#  * stochastic
#  * sequential
#  * dynamic
#  * continuous
#  * multi-agent
#
#
# * The environment largely determines the agent type.

# %% [markdown]
# ----

# %% [markdown]
# #### Actuators:

# %% [markdown]
# * Types, physical characteristics and mechanical properties.
#
# <br>
#
# <div class="alert alert-success">
#
# <font color=black><b>Example</b>: Designing an automated taxi driver</font><br>
#
# <br>
#
# - <font color=black>Performance measure? safety, reach destination, maximise profits, obey laws, passenger comfort...</font><br>
# - <font color=black>Environment:? urban streets, motorways, traffic, pedestrians, weather, customers...</font><br>
# - <font color=black><b>Actuators</b>? steer, accelerate, brake, horn, speak/display,...</font><br>
# - <font color=black>Sensors? </font><br>
#
# </div>

# %% [markdown]
# ----

# %% [markdown]
# #### Sensors:

# %% [markdown]
# * Types, physical characteristics, mechanical properties and modality of the percept (speech, audio, image, location, etc)
#
# <br>
#
# <div class="alert alert-success">
# <font color=black><b>Example</b>: Designing an automated taxi driver</font><br>
# <br>
# - <font color=black>Performance measure? safety, reach destination, maximise profits, obey laws, passenger comfort...</font><br>
# - <font color=black>Environment:? urban streets, motorways, traffic, pedestrians, weather, customers...</font><br>
# - <font color=black>Actuators? steer, accelerate, brake, horn, speak/display,...</font><br>
# - <font color=black><b>Sensors?</b> video, accelerometers, GPS, engine sensors, keyboard,...</font><br>
# </div>

# %% [markdown]
# ----

# %% [markdown]
# ### PEAS: More examples

# %% [markdown]
# <img src="resources/figure25_peas.jpg" width="800px">
# <small><center>Figure courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center></small>

# %% [markdown]
# ----

# %% [markdown]
# ### Agent structure and types

# %% [markdown]
# <img src="resources/figure21_baseagent2.png" width="600px">
# <center>A basic agent</center>
#
# <br>
#
# <img src="resources/figure_vac.jpg" width="1500px">
# <center>The vacuum cleaner revisited</center>
# <small><center>Figure courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center></small>
# <br>

# %% [markdown]
# ----

# %% [markdown]
# #### Program as lookup

# %% [markdown]
# <img src="resources/figure27_table.jpg" width="700px">
# <small><center>Figure courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center></small>
#
# <br>
#
# - Does not scale very well if the number of unique states increase, e.g. consider a real image with 1M pixels and tabulating all possible outcomes in order to be able to make a decision...

# %% [markdown]
# ----

# %% [markdown]
# ##### Program as condition-action-rules

# %% [markdown]
# <img src="resources/figure28_reflefunction_corrected.jpg" width="700px">
# <small><center>Figure courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center></small>
#
# - Works for a limited set of discrete states and rules, but consider manually making rules to classify faces in images this way (a feasible way involved so-called decision trees).

# %% [markdown]
# ----

# %% [markdown]
# #### Simple reflex agent

# %% [markdown]
# <img src="resources/figure29_reflex.png" width="600px">
# <center>Image: AIMA 2.9 - Reflextive</center>
#
# * Maps directly from percept to actions
# * Cannot handle partial observability (e.g. a percept missing or
#     * E.g. if our taxi driver is stuck in bad weather and cannot clearly see the brake light of the car in front, i.e. cannot determine car-in-front-braking, and will have to never break or always break.
#
#
# Skeleton:
#
# <img src="resources/figure29_reflex_codesimple.png" width="700px">
# <center>Figure courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center>

# %% [markdown]
# ----

# %% [markdown]
# #### Simple reflex agent - with state / model

# %% [markdown]
# <img src="resources/figure211_reflex_state.png" width="600px">
# <center>Image: AIMA 2.11 - Reflex agent with a model of the world</center>
#
# * A model of the world allows the agent to handle partial observability
#     * E.g. our taxi driver has run into bad weather and cannot clearly see the tail lights of the car in front, what should he do? With the model based on previous percepts he might be able to reason (a best guess) that the car in front as just slowed down and not breaking anymore, and we can continue without breaking.
#
# <br>
#
# Skeleton:
#
# <img src="resources/figure212_reflexcode.jpg" width="700px">
# <small><center>Figure courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center><small>

# %% [markdown]
# ----

# %% [markdown]
# #### Goal-based

# %% [markdown]
# <img src="resources/figure213_goal.png" width="600px">
# <small><center>Image: AIMA 2.13 - Goal-based agent. Figure courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center></small>
#
# <br>
#
# * A specific goal, which can be obtained in one or typically more steps.
#      * E.g. our taxi driver needs to go to Inverness from Glasgow and at any junction he can go (left, right, straight, turn), what should he do ?
# * Involves questions such as: "What will happen if I do this - and will it get me closer to the goal". This is not the case in reflex agents: they map directly from percepts to actions.
# * Solved by search and planning techniques (which we will consider soon) .

# %% [markdown]
# ----

# %% [markdown]
# #### Utility-based

# %% [markdown]
# <img src="resources/figure214_utility.png" width="600px">
# <small><center>Image: AIMA 2.14 - Utility-based agent. Figure courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center></small>
#
# <br>
# <br>
# <br>
#
# * Still a goal, but be "happy" when you have reached it.
# * When there are two ways to obtain the goal, utility provides a tradeoff.
# * Potential to cope with uncertainty and partial observability.
# * Solved by formulating a number of utility functions, and using search/planning and continuous optimization methods to optimize the expected utility.

# %% [markdown]
# ----

# %% [markdown]
# #### ... they can all learn

# %% [markdown]
# <img src="resources/figure215_learning.png" width="600px">
# <small><center>Image: AIMA 2.15 - Learning agent. Figure courtesy of Stuart Russell and Peter Norvig, Artificial Intelligence: A Modern Approach</center></small>

# %% [markdown]
# <br>
#
# * Nature (innate qualities) vs. nurture (personal experience).
# * If the agent is only dependent on built-in knowledge it lacks autonomy.
# * A system is autonomous to the extent that its behaviour is determined by its own experience. Just as animals are born with reflexes and instincts to survive to the point they can learn for themselves, the agent will need some pre-programmed knowledge from the designer.
#
#
# .... perhaps a "child agent" that can learn is the way to obtain general AI / human level AI ?

# %% [markdown]
# ----

# %% [markdown]
# ### Summary

# %% [markdown]
# * AI motivation & introduction
# * Course overview
# * A peek at a general framework
#
# * Introduced an *__agent__* as something that perceives and acts in an environment
# * Proposed a design (and evaluation) principle based on rationality
# * PEAS
#  * Performance
#  * Environment (and Task Environment)
#  * Actuators
#  * Sensors
# * An ideal (here rational) agent takes action that is expected to maximise its performance measure, given percept sequence so far.
#     * Reflex-based agents
#     * Agents with internal state
#     * Goal-based agents
#     * Utility-based agents
# * Autonomy through (machine) learning

# %% [markdown]
# ---

# %% [markdown]
# ### What should I know ?

# %% [markdown]
# <div class="alert alert-danger">
# <font color=black>
# <b>Reading</b>: <br>
# - AIMA: Chapter 1 and 2 <br>
# - Computing Machinery and Intelligence, A. M. Turing, 1950 <br>
# - Try the weekly quiz  <br>
#
# No need to memorize names and dates of individual scientist and events.
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font color=black>
# <b>Learning objectives:</b><br>
# - Become familiar with the history of AI, its definition and its development<br>
# - Understand the definition of rational agents<br>
# - Be able to take a description of an application domain and break it down to a PEAS description<br>
# - Be able to explain the basic agent types and it's limitations<br>
# - Be able to analyse and discuss the features of an environment (e.g. accessibility, deterministic, dynamic, continuous, episodic)<br>
# </font>
# <br>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font color=black>
# <b>Key concepts</b>: Agents, PEAS, Task Environment, Rationality, Agent types (reflex-based, goal-based, utility-based, learning-based)
# </font>
# </div>

# %% [markdown]
# ----
